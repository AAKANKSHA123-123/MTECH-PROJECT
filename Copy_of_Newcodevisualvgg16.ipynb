# %% [markdown]
# <a href="https://colab.research.google.com/github/AAKANKSHA123-123/MTECH-PROJECT/blob/main/Copy_of_Newcodevisualvgg16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction and data collection**

# %%
#importing packages
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import json
from google.colab import drive

# %%
import tensorflow as tf

# We'll generate plots of attention in order to see which parts of an image
# our model focuses on during captioning
#import matplotlib.pyplot as plt

# Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import re
import numpy as np
import pandas as pd
import os
import time
import json
import collections
import operator
from glob import glob
from PIL import Image
import pickle
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import numpy as np
from tensorflow import reshape
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, Embedding, LSTM, Activation,ZeroPadding1D,Conv1D

print("Done imports")
# Out:
# Done imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %% [markdown]
# **Mounting drive for saving data**

# %%
drive.mount('/content/drive/', force_remount=True) #mouting the drive
# Out:
# Mounted at /content/drive/

# %% [markdown]
# **Downloading COCO images**

# %% [markdown]
# **Downloading VQA Questions**

# %%
annotation_zip = tf.keras.utils.get_file('captions.zip',cache_subdir=os.path.abspath('.'),origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip',extract = True)

annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'

name_of_zip = 'train2014.zip'
if not os.path.exists(os.path.abspath('.')+'/' + name_of_zip):
  image_zip = tf.keras.utils.get_file(name_of_zip,cache_subdir=os.path.abspath('.'),origin='http://images.cocodataset.org/zips/train2014.zip',extract=True)
  PATH = os.path.dirname(image_zip)+'/train2014'
else:
  PATH = os.path.abspath('.')+'/train2014'
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 4s 0us/step
# 252887040/252872794 [==============================] - 4s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
# 13510574080/13510573713 [==============================] - 309s 0us/step
# 13510582272/13510573713 [==============================] - 309s 0us/step

# %%
print(PATH)
#!wget https://s3.amazonaws.com/cvmlp/vqs/mscoco/vqa/v2_Questions_Train_mscoco.zip
#!unzip -a v2_Questions_Train_mscoco.zip
# !wget https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Annotations_Train_mscoco.zip
# !unzip -a v2_Annotations_Train_mscoco.zip
# !wget https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Train_mscoco.zip
# !unzip -a v2_Questions_Train_mscoco.zip
# Out:
# /content/train2014
# --2021-10-28 15:11:26--  https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Annotations_Train_mscoco.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.204.13
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.204.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21708861 (21M) [application/zip]
# Saving to: ‘v2_Annotations_Train_mscoco.zip’
#
# v2_Annotations_Trai 100%[===================>]  20.70M  40.3MB/s    in 0.5s
#
# 2021-10-28 15:11:27 (40.3 MB/s) - ‘v2_Annotations_Train_mscoco.zip’ saved [21708861/21708861]
#
# Archive:  v2_Annotations_Train_mscoco.zip
#   inflating: v2_mscoco_train2014_annotations.json  [text]
# --2021-10-28 15:11:30--  https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Train_mscoco.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.204.13
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.204.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7239401 (6.9M) [application/zip]
# Saving to: ‘v2_Questions_Train_mscoco.zip’
#
# v2_Questions_Train_ 100%[===================>]   6.90M  22.5MB/s    in 0.3s
#
# 2021-10-28 15:11:30 (22.5 MB/s) - ‘v2_Questions_Train_mscoco.zip’ saved [7239401/7239401]
#
# Archive:  v2_Questions_Train_mscoco.zip
#   inflating: v2_OpenEnded_mscoco_train2014_questions.json  [text]

# %%
# read the json file
question_file_path = 'v2_OpenEnded_mscoco_train2014_questions.json'
with open(question_file_path, 'r') as f:
    questions = json.load(f)

print("Total Number Questions is : ",len(questions['questions']))
# Out:
# Total Number Questions is :  443757

# %% [markdown]
# **Added code from separate image model**

# %%
#Storing the captions and image file name in vectors
import collections
import operator

annotation_file = 'v2_mscoco_train2014_annotations.json'

with open(annotation_file,'r') as f:
  annotations = json.load(f)



all_answers = []
all_answers_qids = []
all_img_name_vector = []

for annot in annotations['annotations']:
  #print(annot)
  ans_dic = collections.defaultdict(int)
  for each in annot['answers']:
    diffans = each['answer']
    if diffans in ans_dic:
      #print(each['answer_confidence'])
      if each['answer_confidence']=='yes':
        ans_dic[diffans]+=4
      if each['answer_confidence']=='maybe':
        ans_dic[diffans]+=2
      if each['answer_confidence']=='no':
        ans_dic[diffans]+=1
    else:
      if each['answer_confidence']=='yes':
        ans_dic[diffans]+=4
      if each['answer_confidence']=='maybe':
        ans_dic[diffans]+=2
      if each['answer_confidence']=='no':
        ans_dic[diffans]+=1

  #print(ans_dic)
  most_fav = max(ans_dic.items(),key=operator.itemgetter(1))[0]
  #print(most_fav)
  caption = '<start>' + most_fav + '<end>'  #each['answer']

  image_id = annot['image_id']
  question_id = annot['question_id']
  full_coco_image_path = PATH  + '/COCO_train2014_' + '%012d.jpg' %(image_id)

  all_img_name_vector.append(full_coco_image_path)
  all_answers.append(caption)
  all_answers_qids.append(question_id)

# %%
all_questions = []
question_ids = []
all_img_name_vector_2 = []


for annot in questions['questions']:
  caption = '<start>' + annot['question'] + '<end>'
  image_id = annot['image_id']
  full_coco_image_path = PATH + '/COCO_train2014_' + '%012d.jpg' %(image_id)
  
  all_img_name_vector_2.append(full_coco_image_path)
  all_questions.append(caption)
  #print(all_questions)
  question_ids.append(annot['question_id'])

# %%
print(questions['questions'][np.random.randint(0,443757)])#new ms coco code
# Out:
# {'image_id': 227828, 'question': 'What condition is the water?', 'question_id': 227828001}

# %%
#Taken from separate image model
print(len(all_img_name_vector),len(all_answers),len(all_answers_qids))
print(all_img_name_vector[10:15],all_answers[10:15],all_answers_qids[10:15])
print(len(all_img_name_vector_2),len(all_questions),len(question_ids))
print(all_img_name_vector_2[10:15],all_questions[10:15],question_ids[10:15])
# Out:
# 443757 443757 443757
# ['/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393223.jpg', '/content/train2014/COCO_train2014_000000393223.jpg'] ['<start>yes<end>', '<start>yes<end>', '<start>contrail<end>', '<start>yes<end>', '<start>white and purple<end>'] [393221000, 393221001, 393221002, 393223000, 393223001]
# 443757 443757 443757
# ['/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393221.jpg', '/content/train2014/COCO_train2014_000000393223.jpg', '/content/train2014/COCO_train2014_000000393223.jpg'] ['<start>Is the sky blue?<end>', '<start>Is there snow on the mountains?<end>', '<start>What is the white streak?<end>', '<start>Is the window open?<end>', '<start>What color is the toothbrush?<end>'] [393221000, 393221001, 393221002, 393223000, 393223001]

# %% [markdown]
# **Shuffling all questions and answers(taken from separate image model)**

# %%
train_answers,train_questions,img_name_vector = shuffle(all_answers,all_questions,all_img_name_vector,random_state=1)
#train_answers,train_questions,img_name_vector = (all_answers,all_questions,all_img_name_vector)
num_examples=50

train_answers = train_answers[:num_examples]
train_questions = train_questions[:num_examples]
img_name_vector =img_name_vector[:num_examples]

print(img_name_vector[0],train_questions[0],train_answers[0])
print(len(img_name_vector),len(train_questions),len(train_answers))
# Out:
# /content/train2014/COCO_train2014_000000573744.jpg <start>Is this a happy animal?<end> <start>yes<end>
# 50 50 50

# %% [markdown]
# **Downloading VQA Annotations**

# %%
annotation_file_path = 'v2_mscoco_train2014_annotations.json'
with open(annotation_file_path, 'r') as f:
    annotations = json.load(f)

# %%
annotations['annotations'][np.random.randint(0,443757)]
# Out:
# {'answer_type': 'other',
#  'answers': [{'answer': 'silliness',
#    'answer_confidence': 'maybe',
#    'answer_id': 1},
#   {'answer': 'paper hats', 'answer_confidence': 'maybe', 'answer_id': 2},
#   {'answer': 'hats', 'answer_confidence': 'maybe', 'answer_id': 3},
#   {'answer': 'hats', 'answer_confidence': 'yes', 'answer_id': 4},
#   {'answer': 'hats', 'answer_confidence': 'yes', 'answer_id': 5},
#   {'answer': 'paper hats', 'answer_confidence': 'yes', 'answer_id': 6},
#   {'answer': 'paper hats', 'answer_confidence': 'yes', 'answer_id': 7},
#   {'answer': 'hats', 'answer_confidence': 'yes', 'answer_id': 8},
#   {'answer': 'hats', 'answer_confidence': 'yes', 'answer_id': 9},
#   {'answer': 'hats', 'answer_confidence': 'yes', 'answer_id': 10}],
#  'image_id': 289329,
#  'multiple_choice_answer': 'hats',
#  'question_id': 289329006,
#  'question_type': 'what are'}

# %%
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# **Data preprocessing**

# %%
#importing packages
import warnings
warnings.filterwarnings("ignore")

import os
import pandas as pd
import numpy as np
import json
import seaborn as sns
import tensorflow as tf

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from wordcloud import WordCloud
from google.colab import drive
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Variables**

# %% [markdown]
# **DATA TRANSFORMATION**
# LOADING QUESTIONS AND ANSWERS

# %%
with open(question_file_path, 'r') as f:
    questions = json.load(f)
    questions = questions["questions"]

with open(annotation_file_path, 'r') as f:
    annotations = json.load(f)
    annotations = annotations["annotations"]

# %%
print("Total Number Questions is : ",len(questions))
# Out:
# Total Number Questions is :  443757

# %%
questions_df = pd.DataFrame(questions).sample(n=10000)
#ques_samp = questions_df.sample(n=100)
#ques_samp.head(5)

questions_df.head(5)
# Out:
#         image_id                                      question  question_id
# 134486    562317  What is the color of the train in the front?    562317000
# 406449    512731                           Are these toy cars?    512731003
# 40551     288440      Is the player trying to get someone out?    288440007
# 85363     286279                           Is the sun shining?    286279000
# 332250    358650                           Is the grass green?    358650004

# %%
annotations_df = pd.DataFrame(annotations).sample(n=10000)
#annot_samp = annotations_df.sample(n=100)
#annot_samp.head(5)
annotations_df.head(5)
print(len(annotations_df))
# Out:
# 10000

# %% [markdown]
# **MERGING QUESTIONS AND ANNOTATIONS**

# %%
data = pd.merge(questions_df,annotations_df,  how='inner', left_on=['image_id','question_id'], right_on = ['image_id','question_id'])
#data_samp = pd.merge(ques_samp,annot_samp,  how='inner', left_on=['image_id','question_id'], right_on = ['image_id','question_id'])
print(len(data))
# Out:
# 208

# %%
data.head(5)
#data_samp.head(5)
# Out:
#    image_id  ... answer_type
# 0    262329  ...       other
# 1    226329  ...       other
# 2     83058  ...      number
# 3    463665  ...       other
# 4    392153  ...       other
#
# [5 rows x 7 columns]

# %%
#currentDirectory = "/content/drive/My Drive/pcase_study_2/"
#os.chdir(currentDirectory)
#currentDirectory = ""
#dataDirectory = currentDirectory + "data/"
#imageDirectory = dataDirectory + "train2014/"
imageDirectory = '/content/train2014'
#question_file_path = dataDirectory + 'v2_OpenEnded_mscoco_train2014_questions.json'
question_file_path = '/content/v2_OpenEnded_mscoco_train2014_questions.json'
#annotation_file_path = dataDirectory + 'v2_mscoco_train2014_annotations.json'
annotation_file_path = '/content/v2_mscoco_train2014_annotations.json'

# %%
imageDirectory = '/content/train2014'
os.chdir(imageDirectory)
imageDirectory = ""

# %%
index = np.random.randint(0,len(data))#263115

img_path =  imageDirectory + 'COCO_train2014_' + '%012d.jpg' % (data['image_id'][index])
img=mpimg.imread(img_path)
imgplot = plt.imshow(img)
plt.axis('off')
plt.show()
print("*"*50)
print("Question : " ,data['question'][index])
print("*"*50)
print("Answer : ", data['multiple_choice_answer'][index])

print(img.shape)
# Out:
# **************************************************
# Question :  What is the continent where these cows live?
# **************************************************
# Answer :  africa
# (427, 640, 3)

# %% [markdown]
# **IMAGES**

# %%
aggregations = {'question': 'count'}
temp = pd.DataFrame(data.groupby(['image_id'],as_index=False).agg(aggregations))
#temp.set_index('image_id', inplace=True)

print(temp)
print(len(temp))
num_of_ques_in_image = temp['question'].values
print("Max number of questions on a image",max(num_of_ques_in_image))
print("Min number of questions on a image",min(num_of_ques_in_image))
print("Mean of questions on a image",np.mean(num_of_ques_in_image))

ax = sns.boxplot(y = 'question', data = temp) 
plt.title("boxplot of Number of questions on a iage")
plt.show()
# Out:
#      image_id  question
# 0        3685         1
# 1        8314         1
# 2        9372         1
# 3       10546         1
# 4       19755         1
# ..        ...       ...
# 201    572089         1
# 202    573749         1
# 203    576012         1
# 204    576527         1
# 205    577759         1
#
# [206 rows x 2 columns]
# 206
# Max number of questions on a image 2
# Min number of questions on a image 1
# Mean of questions on a image 1.0097087378640777

# %% [markdown]
# **IMAGES THAT HAVE MAXIMUM NUMBER OF QUESTIONS**

# %% [markdown]
# **Duplicate questions on same image**

# %%
aggregations = {'question_id':'count', 'multiple_choice_answer': lambda x: " || ".join(x)}
temp = pd.DataFrame(data.groupby(['image_id','question'],as_index=False).agg(aggregations)).rename(columns={'question_id':'count'})
temp = temp[temp['count']>1]
temp
# Out:
# Empty DataFrame
# Columns: [image_id, question, count, multiple_choice_answer]
# Index: []

# %% [markdown]
# **Question type**

# %%
data.question_type.unique()
# Out:
# array(['what is the', 'what is', 'how many people are', 'what kind of',
#        'what is the color of the', 'what color is the', 'what are',
#        'is there a', 'what', 'what is the man', 'how many',
#        'what color are the', 'what number is', 'what does the',
#        'none of the above', 'is there', 'is the', 'are there any',
#        'are these', 'are the', 'where is the', 'are there',
#        'what are the', 'is this', 'how many people are in', 'what color',
#        'what color is', 'which', 'what is in the', 'is', 'what sport is',
#        'is he', 'what is this', 'what is on the', 'what type of',
#        'who is', 'what time', 'what is the woman', 'does this', 'do',
#        'does the', 'is this an', 'what brand', 'are', 'is this a',
#        'are they', 'has', 'is that a', 'could', 'is the man',
#        'what room is', 'what is the person', 'is it', 'why'], dtype=object)

# %%
print("Number of unique Question type in dataset : ",len(data.question_type.unique()))
# Out:
# Number of unique Question type in dataset :  54

# %%
def getFrequnctDict(data,column,isJoin=False):
    column_frequency = {}

    for _row in data[column]:
        if isJoin:
            _row = "_".join(_row.split())
        if(column_frequency.get(_row,-1) > 0):
            column_frequency[_row] += 1
        else:
            column_frequency[_row] = 1

    return column_frequency

def lineChart(data,column,top=20,isJoin=False):
    column_frequncy = getFrequnctDict(data,column,isJoin)
    sort_column_frequncy = sorted(list(column_frequncy.items()),key = lambda x: x[1],reverse=True)
    total_samples =  len(data)

    plt.plot([x[1]for x in sort_column_frequncy[:top]])
    i=np.arange(top)
    plt.title("Frequency of top " + str(top) + " " + column )
    plt.xlabel("Tags")
    plt.ylabel("Counts")
    plt.xticks(i,[x[0] for x in sort_column_frequncy[:top]])
    plt.xticks(rotation=90)
    plt.show()
    return sort_column_frequncy

def plotWordCloud(data,column,isJoin=False):
    column_frequncy = getFrequnctDict(data,column,isJoin)
    #https://www.geeksforgeeks.org/generating-word-cloud-python/
    wordcloud = WordCloud(width = 800, height = 800, 
                    background_color ='white', 
                    stopwords = None, 
                    min_font_size = 10).generate_from_frequencies(column_frequncy)
    # plot the WordCloud image     
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.title("WordCloud on "+ column)  
    plt.show()

# %%
plotWordCloud(data, 'question_type')
question_type_frequncy = lineChart(data, 'question_type', top = 30)

# %%
for _type,_count in question_type_frequncy[:10]:
    print("Percentage of '" + _type + "' Type of Questions in Dataset is ", str(100*_count/len(data)))
# Out:
# Percentage of 'how many' Type of Questions in Dataset is  10.576923076923077
# Percentage of 'what' Type of Questions in Dataset is  7.6923076923076925
# Percentage of 'what is the' Type of Questions in Dataset is  6.25
# Percentage of 'is the' Type of Questions in Dataset is  5.769230769230769
# Percentage of 'is this' Type of Questions in Dataset is  4.8076923076923075
# Percentage of 'none of the above' Type of Questions in Dataset is  4.326923076923077
# Percentage of 'what is' Type of Questions in Dataset is  3.8461538461538463
# Percentage of 'what color is the' Type of Questions in Dataset is  3.3653846153846154
# Percentage of 'is' Type of Questions in Dataset is  2.8846153846153846
# Percentage of 'how many people are' Type of Questions in Dataset is  2.4038461538461537

# %% [markdown]
# **ANSWERS**

# %%
data['answer_type'].unique()
# Out:
# array(['other', 'number', 'yes/no'], dtype=object)

# %%
answer_type_frequncy = lineChart(data, 'answer_type', top = 3)

# %%
for _type,_count in answer_type_frequncy:
    print("Percentage of '" + _type + "' Type of Answers in Dataset is ", str(100*_count/len(data)) )
# Out:
# Percentage of 'other' Type of Answers in Dataset is  49.51923076923077
# Percentage of 'yes/no' Type of Answers in Dataset is  33.65384615384615
# Percentage of 'number' Type of Answers in Dataset is  16.826923076923077

# %%
sns.countplot(data["multiple_choice_answer"].apply(lambda x: len(x.split())).values)
plt.title("Number of words in Answers vs Distrubution")
plt.xlabel("Number of words in Answers")
plt.ylabel("Distrubution")
plt.show()

# %% [markdown]
# **QUESTION**

# %%
sns.countplot(data["question"].apply(lambda x: len(x.split())).values)
plt.title("Length of the questions vs Distrubution")
plt.xlabel("Length of the questions")
plt.ylabel("Distrubution")
plt.show()

# %% [markdown]
# **QUESTION TYPE AND ANSWER**

# %%
temp = data
top_question = [x[0] for x in question_type_frequncy[:50]]
print(top_question)
top_aswers = [x[0] for x in answer_type_frequncy[:50]]
print(top_aswers)
temp = data[(data['question_type'].isin(top_question) | data['multiple_choice_answer'].isin(top_aswers))]

aggregations = {'question': 'count'}
temp = pd.DataFrame(temp.groupby(['question_type','multiple_choice_answer'],as_index= False).agg(aggregations))
temp = temp[temp['question']>=10]
temp = temp.pivot(index='question_type', columns='multiple_choice_answer', values='question')
#print(temp)
# Out:
# ['how many', 'what', 'what is the', 'is the', 'is this', 'none of the above', 'what is', 'what color is the', 'is', 'how many people are', 'what kind of', 'is this a', 'is there', 'where is the', 'are there', 'is he', 'what time', 'is it', 'what are', 'is there a', 'what is the man', 'what color are the', 'what does the', 'what are the', 'what color', 'what sport is', 'what type of', 'does the', 'what is the person', 'are there any', 'are these', 'are the', 'which', 'what is in the', 'what is this', 'what is on the', 'does this', 'what is the color of the', 'what number is', 'how many people are in', 'what color is', 'who is', 'what is the woman', 'do', 'is this an', 'what brand', 'are', 'are they', 'has', 'is that a']
# ['other', 'yes/no', 'number']

# %% [markdown]
# **QUESTION TYPE VS ANSWER**

# %%
fig = plt.figure(figsize=(80,30))
fig.tight_layout() 
count = 1
colorCodes = [ "#E18719", "#287819", "#2D6EAA", "#E6AF23", "#666666","#724D8D", "#EAAB5E", "#73A769","#93785F",
              "#C97B7B", "#81A8CC", "#EDC765", "#858585","#957AA9", "#F3CFA3","#B4D0AF", "#BEADA0", "#E4BDBD", 
              "#ABC5DD", "#F4DB9C", "#A3A3A3"]

for _type,_ in question_type_frequncy[:12]:

    percentage = str(round((len(data[data['question_type']==_type])/len(data))*100,1))+'%'

    plt.subplot(4, 3, count)
    temp = data[data['question_type']==_type]
    ax = temp['multiple_choice_answer'].value_counts()[:10][::-1].plot(kind='barh', figsize=(20,15),color=colorCodes[count-1], fontsize=13)
    ax.set_alpha(0.8)   
    ax.set_title("Question Type:  '" + _type + "' (" + percentage + ") vs Answer" , fontsize=18)
    ax.set_ylabel("Answers", fontsize=18)
    ax.get_xaxis().set_visible(False)


    for i in ax.patches:
        ax.text(i.get_width()/2, i.get_y(), str(round((i.get_width()/len(temp))*100, 2))+'%' + "(" +
                str(round((i.get_width()/len(data))*100, 2))+'%' +")", fontsize=10,color='black')
        
    count += 1

fig.tight_layout()
plt.show()

# %% [markdown]
# **ANSWERS VS QUESTION TYPE**

# %%
fig = plt.figure()
fig.tight_layout() 
count = 1

colorCodes = [ "#E18719", "#287819", "#2D6EAA", "#E6AF23", "#666666","#724D8D", "#EAAB5E", "#73A769","#93785F",
              "#C97B7B", "#81A8CC", "#EDC765", "#858585","#957AA9", "#F3CFA3","#B4D0AF", "#BEADA0", "#E4BDBD", 
              "#ABC5DD", "#F4DB9C", "#A3A3A3"]

answer_frequncy = sorted(list(getFrequnctDict(data,'multiple_choice_answer').items()),key = lambda x: x[1],reverse=True)

for _type,_ in answer_frequncy[:12]:

    percentage = str(round((len(data[data['multiple_choice_answer']==_type])/len(data))*100,1))+'%'

    plt.subplot(4, 3, count)
    temp = data[data['multiple_choice_answer']==_type]
    ax = temp['question_type'].value_counts()[:10][::-1].plot(kind='barh', figsize=(20,15),color=colorCodes[count-1], fontsize=13)
    ax.set_alpha(0.8)   
    ax.set_title("Answer: '" + _type + "' (" + percentage + ") vs Question Type" , fontsize=18)
    ax.set_ylabel("Question Type", fontsize=18)
    ax.get_xaxis().set_visible(False)

    for i in ax.patches:
        ax.text(i.get_width()/2, i.get_y(), str(round((i.get_width()/len(temp))*100, 2))+'%' + "(" +
                str(round((i.get_width()/len(data))*100, 2))+'%' +")", fontsize=14,color='black')
        
    count += 1

fig.tight_layout()
plt.show()

# %% [markdown]
# **CHECKING IF ACTUAL ANSWER IS SAME AS PERSONS ANSWERS**

# %%
def getPeopleAnswer(answers):
    answers_dict = {}
    score_dict = { 'yes' : 3, 'maybe' : 2, 'no' : 1 }
    for _answer in answers:
        score = score_dict[_answer['answer_confidence']]
        if answers_dict.get(_answer['answer'],-1) != -1 :
            answers_dict[_answer['answer']] += score
        else:
            answers_dict[_answer['answer']] = score

    return sorted(list(answers_dict.items()),key = lambda x: x[1],reverse=True)[0][0]

# %%
#data['derived_answer'] =  data["answers"].apply(lambda x: getPeopleAnswer(x))

# %%
#data[ data['derived_answer'] != data['multiple_choice_answer']]

# %%
# !pwd
# Out:
# /content/train2014

# %%
dataDDirectory ='/content/drive/MyDrive/newresults'
os.chdir(dataDDirectory)
# !pwd
data.to_csv(dataDDirectory + 'data.csv')
# Out:
# /content/drive/MyDrive/newresults

# %%
os.listdir(dataDDirectory)
# Out:
# ['Models',
#  '.ipynb_checkpoints',
#  'data',
#  'filenamert.pickle',
#  'myhdf5.h5',
#  'myhdfff5.hdf5',
#  'training.hdf5',
#  'validation.hdf5',
#  'VQA_MODEL_WEIGHTS.hdf5',
#  'my_vqa_model']

# %% [markdown]
# **Modelling**

# %%
import warnings
warnings.filterwarnings("ignore")

import pickle
import os
import pandas as pd
import random as rn
import numpy as np
import tensorflow as tf
from google.colab import drive
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.regularizers import l1,l2
from tqdm import tqdm
import heapq
from sklearn.utils import shuffle
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from sklearn.model_selection import train_test_split
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Variables**

# %%
currentDirectory = "/content/drive/MyDrive/newresults/"
os.chdir(currentDirectory)
currentDirectory = ""
dataDirectory = currentDirectory + "data/"
#imageDirectory = dataDirectory + "train2014/"
imageDirectory = '/content/train2014/'
imageNumpyDirectory = dataDirectory + "train2014_Numpy" + ''

modelsDirectory = currentDirectory + "Models/"


img_width = 224
img_height = 224

#BATCH_SIZE = 64
BATCH_SIZE = 1
BUFFER_SIZE = 300

# %%
#len(os.listdir(imageNumpyDirectory))
data = pd.read_csv(dataDDirectory + 'data.csv')
X_train, X_val = train_test_split(data, test_size=0.2, random_state=42)

# %% [markdown]
# **Creating answer vectors**

# %%
contractions = { 
"ain't": "am not","aren't": "are not","can't": "cannot","can't've": "cannot have","'cause": "because","could've": "could have","couldn't": "could not",
"couldn't've": "could not have","didn't": "did not","doesn't": "does not","don't": "do not","hadn't": "had not","hadn't've": "had not have",
"hasn't": "has not","haven't": "have not","he'd": "he would","he'd've": "he would have","he'll": "he will","he's": "he is","how'd": "how did",
"how'll": "how will","how's": "how is","i'd": "i would","i'll": "i will","i'm": "i am","i've": "i have","isn't": "is not","it'd": "it would",
"it'll": "it will","it's": "it is","let's": "let us","ma'am": "madam","mayn't": "may not","might've": "might have","mightn't": "might not",
"must've": "must have","mustn't": "must not","needn't": "need not","oughtn't": "ought not","shan't": "shall not","sha'n't": "shall not","she'd": "she would",
"she'll": "she will","she's": "she is","should've": "should have","shouldn't": "should not","that'd": "that would","that's": "that is","there'd": "there had",
"there's": "there is","they'd": "they would","they'll": "they will","they're": "they are","they've": "they have","wasn't": "was not","we'd": "we would",
"we'll": "we will","we're": "we are","we've": "we have","weren't": "were not","what'll": "what will","what're": "what are","what's": "what is",
"what've": "what have","where'd": "where did","where's": "where is","who'll": "who will","who's": "who is","won't": "will not","wouldn't": "would not",
"you'd": "you would","you'll": "you will","you're": "you are"
}

def preprocess_english(text):
    '''Given a text this function removes the punctuations and returns the remaining text string'''
    new_text = ""
    text = text.lower()
    i = 0
    for word in text.split():
      if i==0:
        new_text = contractions.get(word,word)
      else:
        new_text = new_text + " " + contractions.get(word,word)
      i += 1
    return new_text.replace("'s", '')

# %%
X_train['multiple_choice_answer'] = X_train['multiple_choice_answer'].apply(lambda x: preprocess_english(x))
X_val['multiple_choice_answer'] = X_val['multiple_choice_answer'].apply(lambda x: preprocess_english(x))

# %%
all_classes = X_train['multiple_choice_answer'].values
class_frequency = {}

for _cls in all_classes:
    if(class_frequency.get(_cls,-1)>0):
        class_frequency[_cls] += 1
    else:
        class_frequency[_cls] = 1

# %%
sort_class_frequency = sorted(list(class_frequency.items()),key = lambda x: x[1],reverse=True)   

plt.plot([x[1] for x in sort_class_frequency[:30]])
i=np.arange(30)
plt.title("Frequency of top 30 Classes")
plt.xlabel("Tags")
plt.ylabel("Counts")
plt.xticks(i,[x[0] for x in sort_class_frequency[:30]])
plt.xticks(rotation=90)
plt.show()

# %%
def getPercentageOfDataCoversGivenNumClasses(n_class, class_frequency, df):
    n_common_class = heapq.nlargest(n_class, class_frequency, key=class_frequency.get)
    count = 0
    for _class in df['multiple_choice_answer'].values:
        if(_class in n_common_class):
            count += 1

    return (count/len(df))*100
    
n_classes = [5,10,20,50,70,100,200,500,750,1000,2000,3000,5000]
percentage_cover = []
for i in n_classes:
    temp = getPercentageOfDataCoversGivenNumClasses(i,class_frequency,X_train)
    percentage_cover.append(temp)
    print("{} most frequent Classes covers {:.2f}% points".format(i,temp))


plt.plot(percentage_cover)
i=np.arange(len(percentage_cover))
plt.title("Percentage of points covers vs number of Classes")
plt.xlabel("Classes")
plt.ylabel("Counts")
plt.xticks(i,n_classes)
plt.show()
# Out:
# 5 most frequent Classes covers 44.58% points
# 10 most frequent Classes covers 51.20% points
# 20 most frequent Classes covers 58.43% points
# 50 most frequent Classes covers 76.51% points
# 70 most frequent Classes covers 88.55% points
# 100 most frequent Classes covers 100.00% points
# 200 most frequent Classes covers 100.00% points
# 500 most frequent Classes covers 100.00% points
# 750 most frequent Classes covers 100.00% points
# 1000 most frequent Classes covers 100.00% points
# 2000 most frequent Classes covers 100.00% points
# 3000 most frequent Classes covers 100.00% points
# 5000 most frequent Classes covers 100.00% points

# %%
common_tags = heapq.nlargest(1000, class_frequency, key = class_frequency.get)
X_train['multiple_choice_answer'] =  X_train['multiple_choice_answer'].apply(lambda x: x if x in common_tags else '')

#removing question which has empty tags
X_train = X_train[X_train['multiple_choice_answer'].apply(lambda x: len(x)>0)]

# %%
label_encoder = LabelBinarizer()
answer_vector_train = label_encoder.fit_transform(X_train['multiple_choice_answer'].apply(lambda x: x).values)
answer_vector_val = label_encoder.transform(X_val['multiple_choice_answer'].apply(lambda x: x).values)

ans_vocab = {l: i for i, l in enumerate(label_encoder.classes_)}

print("Number of clasess: ", len(ans_vocab))
print("Shape of Answer Vectors in Train Data: ", answer_vector_train.shape)
print("Shape of Answer Vectors in Validation Data: ", answer_vector_val.shape)
# Out:
# Number of clasess:  89
# Shape of Answer Vectors in Train Data:  (166, 89)
# Shape of Answer Vectors in Validation Data:  (42, 89)

# %% [markdown]
# **Creating Image features using VGG19**

# %%
import pickle

def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (img_width, img_height))
    img = tf.keras.applications.vgg19.preprocess_input(img)
    img = img * (1./255)
    return img, image_path

def VGG19_Top():
    model = tf.keras.applications.VGG16(include_top=False,weights='imagenet',input_shape = (img_width, img_height,3))
    #model = tf.keras.applications.VGG19(include_top=False,weights='imagenet',input_shape = (img_width, img_height,3))
    input_layer = model.input
    hidden_layer = model.layers[-1].output 
    model = tf.keras.Model(input_layer, hidden_layer)
    return model

def generateImageFeatures(images):
    model = VGG19_Top()
    all_image_dict = {}
  
    img_ds = tf.data.Dataset.from_tensor_slices(images)
    img_ds = img_ds.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)
    
    for batch_img, batch_path in img_ds:
        batch_img_features = model(batch_img)
        #print(batch_img_features)

        for img_features, path in zip(batch_img_features, batch_path):
            image_path = path.numpy().decode("utf-8")
            print(image_path)
            
            
            image_path = image_path.replace(imageDirectory,imageNumpyDirectory).replace('.jpg',"")
            print(image_path)
            np.save(image_path, img_features.numpy())
            all_image_dict[image_path] = img_features.numpy()
            print("Printing image features")
            #print(all_image_dict[image_path])
    
    with open('filenamert.pickle', 'wb') as handle:
        pickle.dump(all_image_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
    return

# !pwd
all_image_path = data['image_id'].apply(lambda x:  imageDirectory + 'COCO_train2014_' + '%012d.jpg' % (x)).unique()

  


generateImageFeatures(all_image_path)
# Out:
# /content/drive/MyDrive/newresults
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# /content/train2014/COCO_train2014_000000262329.jpg
# data/train2014_NumpyCOCO_train2014_000000262329
# Printing image features
# /content/train2014/COCO_train2014_000000226329.jpg
# data/train2014_NumpyCOCO_train2014_000000226329
# Printing image features
# /content/train2014/COCO_train2014_000000083058.jpg
# data/train2014_NumpyCOCO_train2014_000000083058
# Printing image features
# /content/train2014/COCO_train2014_000000463665.jpg
# data/train2014_NumpyCOCO_train2014_000000463665
# Printing image features
# /content/train2014/COCO_train2014_000000392153.jpg
# data/train2014_NumpyCOCO_train2014_000000392153
# Printing image features
# /content/train2014/COCO_train2014_000000083256.jpg
# data/train2014_NumpyCOCO_train2014_000000083256
# Printing image features
# /content/train2014/COCO_train2014_000000019755.jpg
# data/train2014_NumpyCOCO_train2014_000000019755
# Printing image features
# /content/train2014/COCO_train2014_000000325850.jpg
# data/train2014_NumpyCOCO_train2014_000000325850
# Printing image features
# /content/train2014/COCO_train2014_000000455350.jpg
# data/train2014_NumpyCOCO_train2014_000000455350
# Printing image features
# /content/train2014/COCO_train2014_000000473676.jpg
# data/train2014_NumpyCOCO_train2014_000000473676
# Printing image features
# /content/train2014/COCO_train2014_000000093280.jpg
# data/train2014_NumpyCOCO_train2014_000000093280
# Printing image features
# /content/train2014/COCO_train2014_000000365996.jpg
# data/train2014_NumpyCOCO_train2014_000000365996
# Printing image features
# /content/train2014/COCO_train2014_000000576012.jpg
# data/train2014_NumpyCOCO_train2014_000000576012
# Printing image features
# /content/train2014/COCO_train2014_000000239745.jpg
# data/train2014_NumpyCOCO_train2014_000000239745
# Printing image features
# /content/train2014/COCO_train2014_000000295280.jpg
# data/train2014_NumpyCOCO_train2014_000000295280
# Printing image features
# /content/train2014/COCO_train2014_000000020770.jpg
# data/train2014_NumpyCOCO_train2014_000000020770
# Printing image features
# /content/train2014/COCO_train2014_000000438478.jpg
# data/train2014_NumpyCOCO_train2014_000000438478
# Printing image features
# /content/train2014/COCO_train2014_000000009372.jpg
# data/train2014_NumpyCOCO_train2014_000000009372
# Printing image features
# /content/train2014/COCO_train2014_000000212712.jpg
# data/train2014_NumpyCOCO_train2014_000000212712
# Printing image features
# /content/train2014/COCO_train2014_000000559995.jpg
# data/train2014_NumpyCOCO_train2014_000000559995
# Printing image features
# /content/train2014/COCO_train2014_000000323153.jpg
# data/train2014_NumpyCOCO_train2014_000000323153
# Printing image features
# /content/train2014/COCO_train2014_000000353511.jpg
# data/train2014_NumpyCOCO_train2014_000000353511
# Printing image features
# /content/train2014/COCO_train2014_000000525913.jpg
# data/train2014_NumpyCOCO_train2014_000000525913
# Printing image features
# /content/train2014/COCO_train2014_000000356888.jpg
# data/train2014_NumpyCOCO_train2014_000000356888
# Printing image features
# /content/train2014/COCO_train2014_000000022164.jpg
# data/train2014_NumpyCOCO_train2014_000000022164
# Printing image features
# /content/train2014/COCO_train2014_000000164496.jpg
# data/train2014_NumpyCOCO_train2014_000000164496
# Printing image features
# /content/train2014/COCO_train2014_000000216042.jpg
# data/train2014_NumpyCOCO_train2014_000000216042
# Printing image features
# /content/train2014/COCO_train2014_000000061803.jpg
# data/train2014_NumpyCOCO_train2014_000000061803
# Printing image features
# /content/train2014/COCO_train2014_000000251862.jpg
# data/train2014_NumpyCOCO_train2014_000000251862
# Printing image features
# /content/train2014/COCO_train2014_000000357429.jpg
# data/train2014_NumpyCOCO_train2014_000000357429
# Printing image features
# /content/train2014/COCO_train2014_000000344924.jpg
# data/train2014_NumpyCOCO_train2014_000000344924
# Printing image features
# /content/train2014/COCO_train2014_000000534771.jpg
# data/train2014_NumpyCOCO_train2014_000000534771
# Printing image features
# /content/train2014/COCO_train2014_000000284351.jpg
# data/train2014_NumpyCOCO_train2014_000000284351
# Printing image features
# /content/train2014/COCO_train2014_000000037823.jpg
# data/train2014_NumpyCOCO_train2014_000000037823
# Printing image features
# /content/train2014/COCO_train2014_000000462879.jpg
# data/train2014_NumpyCOCO_train2014_000000462879
# Printing image features
# /content/train2014/COCO_train2014_000000262285.jpg
# data/train2014_NumpyCOCO_train2014_000000262285
# Printing image features
# /content/train2014/COCO_train2014_000000063698.jpg
# data/train2014_NumpyCOCO_train2014_000000063698
# Printing image features
# /content/train2014/COCO_train2014_000000535517.jpg
# data/train2014_NumpyCOCO_train2014_000000535517
# Printing image features
# /content/train2014/COCO_train2014_000000548836.jpg
# data/train2014_NumpyCOCO_train2014_000000548836
# Printing image features
# /content/train2014/COCO_train2014_000000211048.jpg
# data/train2014_NumpyCOCO_train2014_000000211048
# Printing image features
# /content/train2014/COCO_train2014_000000125548.jpg
# data/train2014_NumpyCOCO_train2014_000000125548
# Printing image features
# /content/train2014/COCO_train2014_000000359719.jpg
# data/train2014_NumpyCOCO_train2014_000000359719
# Printing image features
# /content/train2014/COCO_train2014_000000163764.jpg
# data/train2014_NumpyCOCO_train2014_000000163764
# Printing image features
# /content/train2014/COCO_train2014_000000228326.jpg
# data/train2014_NumpyCOCO_train2014_000000228326
# Printing image features
# /content/train2014/COCO_train2014_000000417602.jpg
# data/train2014_NumpyCOCO_train2014_000000417602
# Printing image features
# /content/train2014/COCO_train2014_000000192327.jpg
# data/train2014_NumpyCOCO_train2014_000000192327
# Printing image features
# /content/train2014/COCO_train2014_000000097229.jpg
# data/train2014_NumpyCOCO_train2014_000000097229
# Printing image features
# /content/train2014/COCO_train2014_000000457981.jpg
# data/train2014_NumpyCOCO_train2014_000000457981
# Printing image features
# /content/train2014/COCO_train2014_000000341110.jpg
# data/train2014_NumpyCOCO_train2014_000000341110
# Printing image features
# /content/train2014/COCO_train2014_000000312536.jpg
# data/train2014_NumpyCOCO_train2014_000000312536
# Printing image features
# /content/train2014/COCO_train2014_000000223526.jpg
# data/train2014_NumpyCOCO_train2014_000000223526
# Printing image features
# /content/train2014/COCO_train2014_000000170695.jpg
# data/train2014_NumpyCOCO_train2014_000000170695
# Printing image features
# /content/train2014/COCO_train2014_000000246411.jpg
# data/train2014_NumpyCOCO_train2014_000000246411
# Printing image features
# /content/train2014/COCO_train2014_000000471697.jpg
# data/train2014_NumpyCOCO_train2014_000000471697
# Printing image features
# /content/train2014/COCO_train2014_000000398428.jpg
# data/train2014_NumpyCOCO_train2014_000000398428
# Printing image features
# /content/train2014/COCO_train2014_000000418536.jpg
# data/train2014_NumpyCOCO_train2014_000000418536
# Printing image features
# /content/train2014/COCO_train2014_000000212019.jpg
# data/train2014_NumpyCOCO_train2014_000000212019
# Printing image features
# /content/train2014/COCO_train2014_000000213936.jpg
# data/train2014_NumpyCOCO_train2014_000000213936
# Printing image features
# /content/train2014/COCO_train2014_000000362108.jpg
# data/train2014_NumpyCOCO_train2014_000000362108
# Printing image features
# /content/train2014/COCO_train2014_000000488634.jpg
# data/train2014_NumpyCOCO_train2014_000000488634
# Printing image features
# /content/train2014/COCO_train2014_000000161762.jpg
# data/train2014_NumpyCOCO_train2014_000000161762
# Printing image features
# /content/train2014/COCO_train2014_000000122563.jpg
# data/train2014_NumpyCOCO_train2014_000000122563
# Printing image features
# /content/train2014/COCO_train2014_000000467685.jpg
# data/train2014_NumpyCOCO_train2014_000000467685
# Printing image features
# /content/train2014/COCO_train2014_000000072909.jpg
# data/train2014_NumpyCOCO_train2014_000000072909
# Printing image features
# /content/train2014/COCO_train2014_000000353270.jpg
# data/train2014_NumpyCOCO_train2014_000000353270
# Printing image features
# /content/train2014/COCO_train2014_000000573749.jpg
# data/train2014_NumpyCOCO_train2014_000000573749
# Printing image features
# /content/train2014/COCO_train2014_000000010546.jpg
# data/train2014_NumpyCOCO_train2014_000000010546
# Printing image features
# /content/train2014/COCO_train2014_000000341736.jpg
# data/train2014_NumpyCOCO_train2014_000000341736
# Printing image features
# /content/train2014/COCO_train2014_000000486482.jpg
# data/train2014_NumpyCOCO_train2014_000000486482
# Printing image features
# /content/train2014/COCO_train2014_000000363117.jpg
# data/train2014_NumpyCOCO_train2014_000000363117
# Printing image features
# /content/train2014/COCO_train2014_000000192145.jpg
# data/train2014_NumpyCOCO_train2014_000000192145
# Printing image features
# /content/train2014/COCO_train2014_000000507460.jpg
# data/train2014_NumpyCOCO_train2014_000000507460
# Printing image features
# /content/train2014/COCO_train2014_000000411155.jpg
# data/train2014_NumpyCOCO_train2014_000000411155
# Printing image features
# /content/train2014/COCO_train2014_000000215631.jpg
# data/train2014_NumpyCOCO_train2014_000000215631
# Printing image features
# /content/train2014/COCO_train2014_000000269958.jpg
# data/train2014_NumpyCOCO_train2014_000000269958
# Printing image features
# /content/train2014/COCO_train2014_000000484504.jpg
# data/train2014_NumpyCOCO_train2014_000000484504
# Printing image features
# /content/train2014/COCO_train2014_000000172171.jpg
# data/train2014_NumpyCOCO_train2014_000000172171
# Printing image features
# /content/train2014/COCO_train2014_000000572089.jpg
# data/train2014_NumpyCOCO_train2014_000000572089
# Printing image features
# /content/train2014/COCO_train2014_000000101479.jpg
# data/train2014_NumpyCOCO_train2014_000000101479
# Printing image features
# /content/train2014/COCO_train2014_000000115117.jpg
# data/train2014_NumpyCOCO_train2014_000000115117
# Printing image features
# /content/train2014/COCO_train2014_000000183435.jpg
# data/train2014_NumpyCOCO_train2014_000000183435
# Printing image features
# /content/train2014/COCO_train2014_000000106545.jpg
# data/train2014_NumpyCOCO_train2014_000000106545
# Printing image features
# /content/train2014/COCO_train2014_000000112253.jpg
# data/train2014_NumpyCOCO_train2014_000000112253
# Printing image features
# /content/train2014/COCO_train2014_000000333863.jpg
# data/train2014_NumpyCOCO_train2014_000000333863
# Printing image features
# /content/train2014/COCO_train2014_000000557266.jpg
# data/train2014_NumpyCOCO_train2014_000000557266
# Printing image features
# /content/train2014/COCO_train2014_000000411571.jpg
# data/train2014_NumpyCOCO_train2014_000000411571
# Printing image features
# /content/train2014/COCO_train2014_000000363370.jpg
# data/train2014_NumpyCOCO_train2014_000000363370
# Printing image features
# /content/train2014/COCO_train2014_000000257243.jpg
# data/train2014_NumpyCOCO_train2014_000000257243
# Printing image features
# /content/train2014/COCO_train2014_000000446094.jpg
# data/train2014_NumpyCOCO_train2014_000000446094
# Printing image features
# /content/train2014/COCO_train2014_000000008314.jpg
# data/train2014_NumpyCOCO_train2014_000000008314
# Printing image features
# /content/train2014/COCO_train2014_000000465744.jpg
# data/train2014_NumpyCOCO_train2014_000000465744
# Printing image features
# /content/train2014/COCO_train2014_000000390365.jpg
# data/train2014_NumpyCOCO_train2014_000000390365
# Printing image features
# /content/train2014/COCO_train2014_000000104919.jpg
# data/train2014_NumpyCOCO_train2014_000000104919
# Printing image features
# /content/train2014/COCO_train2014_000000354392.jpg
# data/train2014_NumpyCOCO_train2014_000000354392
# Printing image features
# /content/train2014/COCO_train2014_000000173258.jpg
# data/train2014_NumpyCOCO_train2014_000000173258
# Printing image features
# /content/train2014/COCO_train2014_000000178116.jpg
# data/train2014_NumpyCOCO_train2014_000000178116
# Printing image features
# /content/train2014/COCO_train2014_000000166092.jpg
# data/train2014_NumpyCOCO_train2014_000000166092
# Printing image features
# /content/train2014/COCO_train2014_000000045785.jpg
# data/train2014_NumpyCOCO_train2014_000000045785
# Printing image features
# /content/train2014/COCO_train2014_000000103419.jpg
# data/train2014_NumpyCOCO_train2014_000000103419
# Printing image features
# /content/train2014/COCO_train2014_000000507252.jpg
# data/train2014_NumpyCOCO_train2014_000000507252
# Printing image features
# /content/train2014/COCO_train2014_000000066328.jpg
# data/train2014_NumpyCOCO_train2014_000000066328
# Printing image features
# /content/train2014/COCO_train2014_000000331479.jpg
# data/train2014_NumpyCOCO_train2014_000000331479
# Printing image features
# /content/train2014/COCO_train2014_000000538422.jpg
# data/train2014_NumpyCOCO_train2014_000000538422
# Printing image features
# /content/train2014/COCO_train2014_000000474800.jpg
# data/train2014_NumpyCOCO_train2014_000000474800
# Printing image features
# /content/train2014/COCO_train2014_000000028976.jpg
# data/train2014_NumpyCOCO_train2014_000000028976
# Printing image features
# /content/train2014/COCO_train2014_000000421734.jpg
# data/train2014_NumpyCOCO_train2014_000000421734
# Printing image features
# /content/train2014/COCO_train2014_000000191197.jpg
# data/train2014_NumpyCOCO_train2014_000000191197
# Printing image features
# /content/train2014/COCO_train2014_000000425724.jpg
# data/train2014_NumpyCOCO_train2014_000000425724
# Printing image features
# /content/train2014/COCO_train2014_000000296846.jpg
# data/train2014_NumpyCOCO_train2014_000000296846
# Printing image features
# /content/train2014/COCO_train2014_000000405752.jpg
# data/train2014_NumpyCOCO_train2014_000000405752
# Printing image features
# /content/train2014/COCO_train2014_000000205668.jpg
# data/train2014_NumpyCOCO_train2014_000000205668
# Printing image features
# /content/train2014/COCO_train2014_000000484742.jpg
# data/train2014_NumpyCOCO_train2014_000000484742
# Printing image features
# /content/train2014/COCO_train2014_000000143629.jpg
# data/train2014_NumpyCOCO_train2014_000000143629
# Printing image features
# /content/train2014/COCO_train2014_000000216674.jpg
# data/train2014_NumpyCOCO_train2014_000000216674
# Printing image features
# /content/train2014/COCO_train2014_000000272309.jpg
# data/train2014_NumpyCOCO_train2014_000000272309
# Printing image features
# /content/train2014/COCO_train2014_000000362919.jpg
# data/train2014_NumpyCOCO_train2014_000000362919
# Printing image features
# /content/train2014/COCO_train2014_000000535448.jpg
# data/train2014_NumpyCOCO_train2014_000000535448
# Printing image features
# /content/train2014/COCO_train2014_000000388772.jpg
# data/train2014_NumpyCOCO_train2014_000000388772
# Printing image features
# /content/train2014/COCO_train2014_000000067935.jpg
# data/train2014_NumpyCOCO_train2014_000000067935
# Printing image features
# /content/train2014/COCO_train2014_000000340976.jpg
# data/train2014_NumpyCOCO_train2014_000000340976
# Printing image features
# /content/train2014/COCO_train2014_000000556088.jpg
# data/train2014_NumpyCOCO_train2014_000000556088
# Printing image features
# /content/train2014/COCO_train2014_000000576527.jpg
# data/train2014_NumpyCOCO_train2014_000000576527
# Printing image features
# /content/train2014/COCO_train2014_000000210997.jpg
# data/train2014_NumpyCOCO_train2014_000000210997
# Printing image features
# /content/train2014/COCO_train2014_000000555951.jpg
# data/train2014_NumpyCOCO_train2014_000000555951
# Printing image features
# /content/train2014/COCO_train2014_000000334277.jpg
# data/train2014_NumpyCOCO_train2014_000000334277
# Printing image features
# /content/train2014/COCO_train2014_000000404983.jpg
# data/train2014_NumpyCOCO_train2014_000000404983
# Printing image features
# /content/train2014/COCO_train2014_000000062619.jpg
# data/train2014_NumpyCOCO_train2014_000000062619
# Printing image features
# /content/train2014/COCO_train2014_000000202912.jpg
# data/train2014_NumpyCOCO_train2014_000000202912
# Printing image features
# /content/train2014/COCO_train2014_000000309096.jpg
# data/train2014_NumpyCOCO_train2014_000000309096
# Printing image features
# /content/train2014/COCO_train2014_000000130053.jpg
# data/train2014_NumpyCOCO_train2014_000000130053
# Printing image features
# /content/train2014/COCO_train2014_000000519843.jpg
# data/train2014_NumpyCOCO_train2014_000000519843
# Printing image features
# /content/train2014/COCO_train2014_000000057830.jpg
# data/train2014_NumpyCOCO_train2014_000000057830
# Printing image features
# /content/train2014/COCO_train2014_000000360813.jpg
# data/train2014_NumpyCOCO_train2014_000000360813
# Printing image features
# /content/train2014/COCO_train2014_000000569946.jpg
# data/train2014_NumpyCOCO_train2014_000000569946
# Printing image features
# /content/train2014/COCO_train2014_000000113879.jpg
# data/train2014_NumpyCOCO_train2014_000000113879
# Printing image features
# /content/train2014/COCO_train2014_000000363494.jpg
# data/train2014_NumpyCOCO_train2014_000000363494
# Printing image features
# /content/train2014/COCO_train2014_000000305414.jpg
# data/train2014_NumpyCOCO_train2014_000000305414
# Printing image features
# /content/train2014/COCO_train2014_000000082676.jpg
# data/train2014_NumpyCOCO_train2014_000000082676
# Printing image features
# /content/train2014/COCO_train2014_000000094569.jpg
# data/train2014_NumpyCOCO_train2014_000000094569
# Printing image features
# /content/train2014/COCO_train2014_000000065776.jpg
# data/train2014_NumpyCOCO_train2014_000000065776
# Printing image features
# /content/train2014/COCO_train2014_000000027002.jpg
# data/train2014_NumpyCOCO_train2014_000000027002
# Printing image features
# /content/train2014/COCO_train2014_000000131742.jpg
# data/train2014_NumpyCOCO_train2014_000000131742
# Printing image features
# /content/train2014/COCO_train2014_000000461517.jpg
# data/train2014_NumpyCOCO_train2014_000000461517
# Printing image features
# /content/train2014/COCO_train2014_000000125512.jpg
# data/train2014_NumpyCOCO_train2014_000000125512
# Printing image features
# /content/train2014/COCO_train2014_000000093953.jpg
# data/train2014_NumpyCOCO_train2014_000000093953
# Printing image features
# /content/train2014/COCO_train2014_000000436558.jpg
# data/train2014_NumpyCOCO_train2014_000000436558
# Printing image features
# /content/train2014/COCO_train2014_000000106168.jpg
# data/train2014_NumpyCOCO_train2014_000000106168
# Printing image features
# /content/train2014/COCO_train2014_000000220408.jpg
# data/train2014_NumpyCOCO_train2014_000000220408
# Printing image features
# /content/train2014/COCO_train2014_000000350741.jpg
# data/train2014_NumpyCOCO_train2014_000000350741
# Printing image features
# /content/train2014/COCO_train2014_000000421689.jpg
# data/train2014_NumpyCOCO_train2014_000000421689
# Printing image features
# /content/train2014/COCO_train2014_000000087653.jpg
# data/train2014_NumpyCOCO_train2014_000000087653
# Printing image features
# /content/train2014/COCO_train2014_000000517182.jpg
# data/train2014_NumpyCOCO_train2014_000000517182
# Printing image features
# /content/train2014/COCO_train2014_000000519713.jpg
# data/train2014_NumpyCOCO_train2014_000000519713
# Printing image features
# /content/train2014/COCO_train2014_000000503015.jpg
# data/train2014_NumpyCOCO_train2014_000000503015
# Printing image features
# /content/train2014/COCO_train2014_000000335098.jpg
# data/train2014_NumpyCOCO_train2014_000000335098
# Printing image features
# /content/train2014/COCO_train2014_000000513873.jpg
# data/train2014_NumpyCOCO_train2014_000000513873
# Printing image features
# /content/train2014/COCO_train2014_000000094210.jpg
# data/train2014_NumpyCOCO_train2014_000000094210
# Printing image features
# /content/train2014/COCO_train2014_000000192395.jpg
# data/train2014_NumpyCOCO_train2014_000000192395
# Printing image features
# /content/train2014/COCO_train2014_000000123041.jpg
# data/train2014_NumpyCOCO_train2014_000000123041
# Printing image features
# /content/train2014/COCO_train2014_000000207424.jpg
# data/train2014_NumpyCOCO_train2014_000000207424
# Printing image features
# /content/train2014/COCO_train2014_000000483487.jpg
# data/train2014_NumpyCOCO_train2014_000000483487
# Printing image features
# /content/train2014/COCO_train2014_000000393230.jpg
# data/train2014_NumpyCOCO_train2014_000000393230
# Printing image features
# /content/train2014/COCO_train2014_000000438701.jpg
# data/train2014_NumpyCOCO_train2014_000000438701
# Printing image features
# /content/train2014/COCO_train2014_000000103383.jpg
# data/train2014_NumpyCOCO_train2014_000000103383
# Printing image features
# /content/train2014/COCO_train2014_000000577759.jpg
# data/train2014_NumpyCOCO_train2014_000000577759
# Printing image features
# /content/train2014/COCO_train2014_000000460988.jpg
# data/train2014_NumpyCOCO_train2014_000000460988
# Printing image features
# /content/train2014/COCO_train2014_000000348510.jpg
# data/train2014_NumpyCOCO_train2014_000000348510
# Printing image features
# /content/train2014/COCO_train2014_000000027046.jpg
# data/train2014_NumpyCOCO_train2014_000000027046
# Printing image features
# /content/train2014/COCO_train2014_000000142034.jpg
# data/train2014_NumpyCOCO_train2014_000000142034
# Printing image features
# /content/train2014/COCO_train2014_000000183585.jpg
# data/train2014_NumpyCOCO_train2014_000000183585
# Printing image features
# /content/train2014/COCO_train2014_000000185818.jpg
# data/train2014_NumpyCOCO_train2014_000000185818
# Printing image features
# /content/train2014/COCO_train2014_000000072391.jpg
# data/train2014_NumpyCOCO_train2014_000000072391
# Printing image features
# /content/train2014/COCO_train2014_000000276267.jpg
# data/train2014_NumpyCOCO_train2014_000000276267
# Printing image features
# /content/train2014/COCO_train2014_000000467911.jpg
# data/train2014_NumpyCOCO_train2014_000000467911
# Printing image features
# /content/train2014/COCO_train2014_000000212636.jpg
# data/train2014_NumpyCOCO_train2014_000000212636
# Printing image features
# /content/train2014/COCO_train2014_000000283018.jpg
# data/train2014_NumpyCOCO_train2014_000000283018
# Printing image features
# /content/train2014/COCO_train2014_000000492435.jpg
# data/train2014_NumpyCOCO_train2014_000000492435
# Printing image features
# /content/train2014/COCO_train2014_000000241945.jpg
# data/train2014_NumpyCOCO_train2014_000000241945
# Printing image features
# /content/train2014/COCO_train2014_000000535160.jpg
# data/train2014_NumpyCOCO_train2014_000000535160
# Printing image features
# /content/train2014/COCO_train2014_000000157205.jpg
# data/train2014_NumpyCOCO_train2014_000000157205
# Printing image features
# /content/train2014/COCO_train2014_000000131665.jpg
# data/train2014_NumpyCOCO_train2014_000000131665
# Printing image features
# /content/train2014/COCO_train2014_000000256968.jpg
# data/train2014_NumpyCOCO_train2014_000000256968
# Printing image features
# /content/train2014/COCO_train2014_000000413012.jpg
# data/train2014_NumpyCOCO_train2014_000000413012
# Printing image features
# /content/train2014/COCO_train2014_000000207503.jpg
# data/train2014_NumpyCOCO_train2014_000000207503
# Printing image features
# /content/train2014/COCO_train2014_000000084273.jpg
# data/train2014_NumpyCOCO_train2014_000000084273
# Printing image features
# /content/train2014/COCO_train2014_000000210849.jpg
# data/train2014_NumpyCOCO_train2014_000000210849
# Printing image features
# /content/train2014/COCO_train2014_000000179408.jpg
# data/train2014_NumpyCOCO_train2014_000000179408
# Printing image features
# /content/train2014/COCO_train2014_000000183453.jpg
# data/train2014_NumpyCOCO_train2014_000000183453
# Printing image features
# /content/train2014/COCO_train2014_000000457503.jpg
# data/train2014_NumpyCOCO_train2014_000000457503
# Printing image features
# /content/train2014/COCO_train2014_000000180046.jpg
# data/train2014_NumpyCOCO_train2014_000000180046
# Printing image features
# /content/train2014/COCO_train2014_000000083454.jpg
# data/train2014_NumpyCOCO_train2014_000000083454
# Printing image features
# /content/train2014/COCO_train2014_000000401921.jpg
# data/train2014_NumpyCOCO_train2014_000000401921
# Printing image features
# /content/train2014/COCO_train2014_000000046260.jpg
# data/train2014_NumpyCOCO_train2014_000000046260
# Printing image features
# /content/train2014/COCO_train2014_000000385849.jpg
# data/train2014_NumpyCOCO_train2014_000000385849
# Printing image features
# /content/train2014/COCO_train2014_000000285138.jpg
# data/train2014_NumpyCOCO_train2014_000000285138
# Printing image features
# /content/train2014/COCO_train2014_000000498782.jpg
# data/train2014_NumpyCOCO_train2014_000000498782
# Printing image features
# /content/train2014/COCO_train2014_000000222555.jpg
# data/train2014_NumpyCOCO_train2014_000000222555
# Printing image features
# /content/train2014/COCO_train2014_000000050636.jpg
# data/train2014_NumpyCOCO_train2014_000000050636
# Printing image features
# /content/train2014/COCO_train2014_000000029600.jpg
# data/train2014_NumpyCOCO_train2014_000000029600
# Printing image features
# /content/train2014/COCO_train2014_000000421383.jpg
# data/train2014_NumpyCOCO_train2014_000000421383
# Printing image features
# /content/train2014/COCO_train2014_000000561323.jpg
# data/train2014_NumpyCOCO_train2014_000000561323
# Printing image features
# /content/train2014/COCO_train2014_000000136563.jpg
# data/train2014_NumpyCOCO_train2014_000000136563
# Printing image features
# /content/train2014/COCO_train2014_000000334953.jpg
# data/train2014_NumpyCOCO_train2014_000000334953
# Printing image features
# /content/train2014/COCO_train2014_000000003685.jpg
# data/train2014_NumpyCOCO_train2014_000000003685
# Printing image features
# /content/train2014/COCO_train2014_000000525640.jpg
# data/train2014_NumpyCOCO_train2014_000000525640
# Printing image features
# /content/train2014/COCO_train2014_000000231029.jpg
# data/train2014_NumpyCOCO_train2014_000000231029
# Printing image features

# %%
print(imageDirectory)
# Out:
# /content/train2014/

# %%
image_paths_train = X_train['image_id'].apply(lambda x:  imageDirectory + 'COCO_train2014_' + '%012d.jpg' % (x)).values
image_paths_val = X_val['image_id'].apply(lambda x:  imageDirectory + 'COCO_train2014_' + '%012d.jpg' % (x)).values
#print(image_paths_train)
with open('filenamert.pickle','rb') as handle:
    all_image_dict = pickle.load(handle)

#with open('all_image_dict_new.pickle', 'rb') as handle:
    #all_image_dict_new = pickle.load(handle)

all_image_dict.update(all_image_dict)
#del all_image_dict_new

# %%
print(type(image_paths_train))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# **Creating question vectors**

# %%
def preprocess_english(text):
    '''Given a text this function removes the punctuations and returns the remaining text string'''
    new_text = "<start>"
    text = text.lower()
    for word in text.split():
      new_text = new_text + " " + contractions.get(word,word)
    new_text = new_text + " <end>"
    return new_text.replace("'s", '')

# %%
X_train['question'] = X_train['question'].apply(lambda x: preprocess_english(x))
X_val['question'] = X_val['question'].apply(lambda x: preprocess_english(x))

# %%
#tokenization
tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token = "<unk>", filters = '!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(X_train['question'].values)
train_question_seqs = tokenizer.texts_to_sequences(X_train['question'].values)
val_question_seqs = tokenizer.texts_to_sequences(X_val['question'].values)

print("Number of words in tokenizer:", len(tokenizer.word_index))
ques_vocab = tokenizer.word_index

#Padding
#tokenizer.word_index['<pad>'] = 0
#tokenizer.index_word[0] = '<pad>'
question_vector_train = tf.keras.preprocessing.sequence.pad_sequences(train_question_seqs, padding='post')
question_vector_val = tf.keras.preprocessing.sequence.pad_sequences(val_question_seqs,padding='post',maxlen=question_vector_train.shape[1])

print("Shape of Question Vectors in Train Data: ", question_vector_train.shape)
print("Shape of Question Vectors in Validation Data: ", question_vector_val.shape)
# Out:
# Number of words in tokenizer: 318
# Shape of Question Vectors in Train Data:  (166, 15)
# Shape of Question Vectors in Validation Data:  (42, 15)

# %% [markdown]
# **Creating dataset**

# %%
def get_imageTensor(img, ques):
    path = img.decode('utf-8').replace(imageDirectory,'/content/drive/MyDrive/newresults/data'+'/'+'train2014_Numpy').replace('.jpg',"") +'.npy'
    
    img_tensor = np.load(path)
    #img_tensor = all_image_dict[img.decode('utf-8')]
    
    return img_tensor, ques

# %%
def createDataset(image_paths,question_vector,answer_vector):
    dataset_input = tf.data.Dataset.from_tensor_slices((image_paths, question_vector.astype(np.float32)))
    dataset_output = tf.data.Dataset.from_tensor_slices((answer_vector.astype(np.float32)))
    # using map to load the numpy files in parallel
    dataset_input = dataset_input.map(lambda img, ques : tf.numpy_function(get_imageTensor, [img, ques], [tf.float32, tf.float32]),
                                      num_parallel_calls=tf.data.experimental.AUTOTUNE)

    # shuffling and batching
    #dataset_input = dataset_input.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
    dataset_input = dataset_input.batch(BATCH_SIZE)
    dataset_output = dataset_output.batch(BATCH_SIZE)#.repeat()
    
    dataset = tf.data.Dataset.zip((dataset_input, dataset_output))
    dataset = dataset.prefetch(buffer_size = tf.data.experimental.AUTOTUNE)

    return dataset

# %%
dataset_train = createDataset(image_paths_train, question_vector_train, answer_vector_train)
dataset_val = createDataset(image_paths_val, question_vector_val, answer_vector_val)
print(dataset_train)
# Out:
# <PrefetchDataset shapes: ((<unknown>, <unknown>), (None, 89)), types: ((tf.float32, tf.float32), tf.float32)>

# %%
print(type(dataset_train))
print(dataset_train)
# Out:
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>
# <PrefetchDataset shapes: ((<unknown>, <unknown>), (None, 89)), types: ((tf.float32, tf.float32), tf.float32)>

# %%
# !pip install deepdish
# Out:
# Collecting deepdish
#   Downloading deepdish-0.3.7-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish) (1.19.5)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish) (3.4.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish) (1.15.0)
# Requirement already satisfied: numexpr>=2.5.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish) (2.7.3)
# Installing collected packages: deepdish
# Successfully installed deepdish-0.3.7

# %%
import deepdish as dd

# %%
hdf5_dict = {
    
    "train_images": image_paths_train,
    "train_ques": question_vector_train.astype(np.float32),
    "train_ans": answer_vector_train.astype(np.float32)
}

# %%
dd.io.save("myhdf5.h5", hdf5_dict,compression=None)

# %%
print(type(dataset_train))
# Out:
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)

# %%
import h5py

# %%
# !pwd
# Out:
# /content/drive/My Drive/newresults

# %%
# create HDF5 file
with h5py.File('myhdfff5.hdf5', 'w') as hf:
    ls = list(hf.keys())
    print('list of dataset in this file: \n',ls)
    dt = h5py.special_dtype(vlen = np.dtype('float64'))
    dset_x_imgtrain = hf.create_dataset('imgg_train', data=image_paths_train)
    print(dset_x_imgtrain)
    dset_x_questrain = hf.create_dataset('quess_train', data=question_vector_train)
    dset_x_anstrain = hf.create_dataset('anss_train', data=answer_vector_train)
    '''for each in dset_x_anstrain:
      print(each)'''
# Out:
# list of dataset in this file:
#  []
# <HDF5 dataset "imgg_train": shape (166,), type "|O">

# %%
# create HDF5 file
with h5py.File('training.hdf5', 'w') as hf:
    ls = list(hf.keys())
    print('list of dataset in this file: \n',ls)
    dt = h5py.special_dtype(vlen = np.dtype('float64'))
    dset_x_imgtrain = hf.create_dataset('imgg_train', data=image_paths_train)
    print(dset_x_imgtrain)
    dset_x_questrain = hf.create_dataset('quess_train', data=question_vector_train)
    dset_x_anstrain = hf.create_dataset('anss_train', data=answer_vector_train)
# Out:
# list of dataset in this file:
#  []
# <HDF5 dataset "imgg_train": shape (166,), type "|O">

# %%
# create HDF5 file
with h5py.File('training.hdf5', 'r') as hf:
    ls = list(hf.keys())
    print('list of dataset in this file: \n',ls)
    img_data = hf.get('imgg_train')
    img_data1 = np.array(img_data)
    print(img_data1.shape)
    ques_data = hf.get('quess_train')
    ques_data1 = np.array(ques_data)
    print(ques_data1.shape)
    anss_data = hf.get('anss_train')
    anss_data1 = np.array(anss_data)
    print(anss_data1.shape)
# Out:
# list of dataset in this file:
#  ['anss_train', 'imgg_train', 'quess_train']
# (166,)
# (166, 15)
# (166, 89)

# %%
# create HDF5 file
with h5py.File('validation.hdf5', 'w') as hf:
    ls = list(hf.keys())
    print('list of dataset in this file: \n',ls)
    dt = h5py.special_dtype(vlen = np.dtype('float64'))
    dset_x_imgval = hf.create_dataset('imgg_val', data=image_paths_val)
    print(dset_x_imgtrain)
    dset_x_quesval = hf.create_dataset('quess_val', data=question_vector_val)
    dset_x_ansval = hf.create_dataset('anss_val', data=answer_vector_val)
# Out:
# list of dataset in this file:
#  []
# <Closed HDF5 dataset>

# %%
print(dset_x_anstrain)
# Out:
# <Closed HDF5 dataset>

# %% [markdown]
# **Baseline Model**

# %%
##fixing numpy RS
np.random.seed(42)

##fixing tensorflow RS
tf.random.set_seed(32)

##python RS
rn.seed(12)

# %%
def callBacksList():
    """
    returns list of callback's
    """
    filepath = modelsDirectory + ModelName + "/best.hdf5"
    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = filepath, monitor = 'val_accuracy', verbose = 1, save_best_only = True, mode = 'auto')
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy', patience = 3)
    early_stop = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 4, verbose = 1)

    #directory for tensorboard to save evnts
    log_dir= modelsDirectory + "logs/fit/" + ModelName + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    os.makedirs(log_dir)

    print("TensorBoard Folder for this Execution",log_dir)#creating TensorBoard call back,this will write all events to given folder
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

    history = tf.keras.callbacks.History()
    callbacks_list = [reduce_lr, early_stop, history, tensorboard_callback, checkpoint]
    return callbacks_list

def Build_BaseModel():
    image_input = tf.keras.layers.Input(shape=(7,7,512))
    question_input = tf.keras.layers.Input(shape=(question_vector_train.shape[1],))

    image_conv_layer1 = tf.keras.layers.Conv2D(filters = 4096, kernel_size = 7 , strides = 1, padding = "valid", activation = 'relu',
                                               kernel_initializer = tf.keras.initializers.he_normal(seed=45))(image_input)

    image_flatten = tf.keras.layers.Flatten()(image_conv_layer1)

    image_dense_1 = tf.keras.layers.Dense(4096, activation = tf.nn.relu, 
                                          kernel_initializer = tf.keras.initializers.he_uniform(seed=54))(image_flatten)
    
    image_dense_2 = tf.keras.layers.Dense(1024, activation = tf.nn.relu, 
                                          kernel_initializer = tf.keras.initializers.he_uniform(seed=32))(image_dense_1)


    # Input 2 Pathway
    question_emb = tf.keras.layers.Embedding(input_dim = len(tokenizer.word_index) + 1, output_dim = 300 ,name = "Embedding_Layer",
                                             embeddings_initializer = tf.keras.initializers.RandomNormal(mean=0, stddev=1, seed=23))(question_input)

    question_lstm = tf.keras.layers.LSTM(1024, 
                                         kernel_initializer = tf.keras.initializers.glorot_uniform(seed=26),
                                         recurrent_initializer = tf.keras.initializers.orthogonal(seed=54),
                                         bias_initializer=tf.keras.initializers.zeros())(question_emb)

    question_flatten = tf.keras.layers.Flatten(name="Flatten_lstm")(question_lstm)

    
    image_question = tf.keras.layers.Multiply()([image_dense_2, question_flatten])


    image_question_dense_1 = tf.keras.layers.Dense(1000, activation = tf.nn.relu,
                                                    kernel_initializer = tf.keras.initializers.he_uniform(seed=19))(image_question)
    
    image_question_dense_2 = tf.keras.layers.Dense(1000, activation = tf.nn.relu, 
                                                   kernel_initializer = tf.keras.initializers.he_uniform(seed=28))(image_question_dense_1)

    output = tf.keras.layers.Dense(len(ans_vocab), activation=tf.nn.softmax, 
                                   kernel_initializer = tf.keras.initializers.glorot_normal(seed=19))(image_question_dense_2)

    # Create Model
    model = tf.keras.models.Model(inputs = [image_input, question_input], outputs = output)
    # Compile
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model

# %%
l2_alpha = 0.001
ModelName = "BaselineModel"
model = Build_BaseModel()
model.summary()
model_vqa = model.save('VQAs_MODEL_WEIGHTS.hdf5')
mode_save = model.save('my_vqas_model')

#model.fit(train_ddata, epochs = 1, callbacks = callBacksList())
#model.fit(train_ddata, epochs = 1, validation_data = dataset_val, callbacks = callBacksList())
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 7, 7, 512)]  0
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 1, 4096)   102764544   input_11[0][0]
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 15)]         0
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 4096)         0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# Embedding_Layer (Embedding)     (None, 15, 300)      95700       input_12[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 4096)         16781312    flatten_3[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 1024)         5427200     Embedding_Layer[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1024)         4195328     dense_15[0][0]
# __________________________________________________________________________________________________
# Flatten_lstm (Flatten)          (None, 1024)         0           lstm_3[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 1024)         0           dense_16[0][0]
#                                                                  Flatten_lstm[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1000)         1025000     multiply_3[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1000)         1001000     dense_17[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 89)           89089       dense_18[0][0]
# ==================================================================================================
# Total params: 131,379,173
# Trainable params: 131,379,173
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: my_vqas_model/assets
# INFO:tensorflow:Assets written to: my_vqas_model/assets

# %%
recons_model = tf.keras.models.load_model('/content/drive/MyDrive/newresults/Models')

# %%
recons_model.load_weights('/content/drive/MyDrive/newresults/Models')
#recons_model.evaluate(dataset_val)

# %%
'''%load_ext tensorboard
# %tensorboard --logdir Models/logs/fit/BaselineModel'''
# Out:
# '%load_ext tensorboard\n%tensorboard --logdir Models/logs/fit/BaselineModel'

# %% [markdown]
# **TESTING**

# %%
#model.load_weights(modelsDirectory + ModelName + "/best.hdf5")
test_idx = np.random.randint(len(X_val), size = 3)
model_vgg = VGG19_Top()
k = 5

for idx in test_idx:
    test_image_id = X_val['image_id'].values[idx]
    test_question = X_val['question'].values[idx]
    actual_answer = X_val['multiple_choice_answer'].values[idx]
    test_image_path = imageDirectory + 'COCO_train2014_' + '%012d.jpg' % (test_image_id)

    test_image_features = model_vgg(tf.expand_dims(load_image(test_image_path)[0], 0))
    test_question_features = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([test_question]),padding='post',
                                                                           maxlen=question_vector_train.shape[0])
    y_pred = recons_model.predict([test_image_features,test_question_features])

    class_indices = tf.math.top_k(y_pred,k=k).indices.numpy()
    percentages = tf.math.top_k(y_pred,k=k).values.numpy()[0] * 100
    predictions = []
    for idx,i in enumerate(class_indices[0]):
        classes = np.zeros((1,1000))
        classes[0][i] = 1
        predictions.append((label_encoder.inverse_transform(classes)[0],percentages[idx]))

    img=mpimg.imread(test_image_path)
    imgplot = plt.imshow(img)
    plt.axis('off')
    plt.show()

    print("Question :", test_question.replace("<start> ","").replace(" <end>",""))
    print("Actual Answer: ", actual_answer)
    print("Top Predicted answers: ",predictions)
    print("*"*150)
# Out:
# Question : which side of rails is the train on?
# Actual Answer:  right
# Top Predicted answers:  [('horse', 4.9784117), ('tennis', 4.7411366), ('1', 4.237472), ('one way', 3.663904), ('2', 3.518453)]
# ******************************************************************************************************************************************************
# Question : how many cakes are there?
# Actual Answer:  3
# Top Predicted answers:  [('tennis', 18.919847), ('horse', 11.451097), ('2', 8.352589), ('phone', 5.966337), ('1', 5.3869944)]
# ******************************************************************************************************************************************************
# Question : what is the person using his foot for?
# Actual Answer:  flush toilet
# Top Predicted answers:  [('tennis', 67.05874), ('horse', 18.70636), ('2', 10.81688), ('phone', 0.60708195), ('1', 0.5956869)]
# ******************************************************************************************************************************************************
